# %%
from data import get_data

# %%
data = get_data()
data.to_csv("./data/data.csv", index=False)

# %%
from numpy import disp


display(data.head())
display(data.info())
display(data.describe())
# Out:
#                    era data_type  feature_shaded_hallucinatory_dactylology  \
# id
# n0007b5abb0c3a25  0001     train                                         3
# n003bba8a98662e4  0001     train                                         4
# n003bee128c2fcfc  0001     train                                         2
# n0048ac83aff7194  0001     train                                         2
# n0055a2401ba6480  0001     train                                         4
#
#                   feature_itinerant_hexahedral_photoengraver  \
# id
# n0007b5abb0c3a25                                           4
# n003bba8a98662e4                                           2
# n003bee128c2fcfc                                           4
# n0048ac83aff7194                                           1
# n0055a2401ba6480                                           1
#
#                   feature_prudent_pileate_oven  \
# id
# n0007b5abb0c3a25                             0
# n003bba8a98662e4                             4
# n003bee128c2fcfc                             0
# n0048ac83aff7194                             3
# n0055a2401ba6480                             4
#
#                   feature_subalpine_apothegmatical_ajax  \
# id
# n0007b5abb0c3a25                                      3
# n003bba8a98662e4                                      4
# n003bee128c2fcfc                                      3
# n0048ac83aff7194                                      0
# n0055a2401ba6480                                      1
#
#                   feature_pistachio_atypical_malison  \
# id
# n0007b5abb0c3a25                                   3
# n003bba8a98662e4                                   0
# n003bee128c2fcfc                                   0
# n0048ac83aff7194                                   3
# n0055a2401ba6480                                   0
#
#                   feature_symmetrical_spongy_tricentenary  \
# id
# n0007b5abb0c3a25                                        1
# n003bba8a98662e4                                        0
# n003bee128c2fcfc                                        3
# n0048ac83aff7194                                        0
# n0055a2401ba6480                                        4
#
#                   feature_ungrounded_transpontine_winder  \
# id
# n0007b5abb0c3a25                                       1
# n003bba8a98662e4                                       4
# n003bee128c2fcfc                                       2
# n0048ac83aff7194                                       3
# n0055a2401ba6480                                       0
#
#                   feature_aseptic_eely_hemiplegia  ...  target_teager2b_20  \
# id                                                 ...
# n0007b5abb0c3a25                                0  ...                0.50
# n003bba8a98662e4                                4  ...                0.50
# n003bee128c2fcfc                                4  ...                1.00
# n0048ac83aff7194                                3  ...                0.25
# n0055a2401ba6480                                4  ...                0.50
#
#                   target_teager2b_60  target_tyler_20  target_tyler_60  \
# id
# n0007b5abb0c3a25                0.50             0.25             0.25
# n003bba8a98662e4                0.50             0.25             0.25
# n003bee128c2fcfc                1.00             1.00             0.75
# n0048ac83aff7194                0.25             0.25             0.25
# n0055a2401ba6480                0.50             0.25             0.50
#
#                   target_victor_20  target_victor_60  target_waldo_20  \
# id
# n0007b5abb0c3a25              0.25              0.25             0.25
# n003bba8a98662e4              0.25              0.00             0.25
# n003bee128c2fcfc              0.75              0.75             0.75
# n0048ac83aff7194              0.50              0.25             0.25
# n0055a2401ba6480              0.25              0.50             0.25
#
#                   target_waldo_60  target_xerxes_20  target_xerxes_60
# id
# n0007b5abb0c3a25             0.00              0.25              0.00
# n003bba8a98662e4             0.25              0.25              0.25
# n003bee128c2fcfc             1.00              0.75              0.75
# n0048ac83aff7194             0.25              0.25              0.25
# n0055a2401ba6480             0.50              0.25              0.50
#
# [5 rows x 2791 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 2746270 entries, n0007b5abb0c3a25 to nfffed717119d633
# Columns: 2791 entries, era to target_xerxes_60
# dtypes: float32(41), int8(2748), object(2)
# memory usage: 7.6+ GB
# None
#        feature_shaded_hallucinatory_dactylology  \
# count                              2.746270e+06
# mean                               1.999915e+00
# std                                1.414359e+00
# min                                0.000000e+00
# 25%                                1.000000e+00
# 50%                                2.000000e+00
# 75%                                3.000000e+00
# max                                4.000000e+00
#
#        feature_itinerant_hexahedral_photoengraver  \
# count                                2.746270e+06
# mean                                 1.999915e+00
# std                                  1.414359e+00
# min                                  0.000000e+00
# 25%                                  1.000000e+00
# 50%                                  2.000000e+00
# 75%                                  3.000000e+00
# max                                  4.000000e+00
#
#        feature_prudent_pileate_oven  feature_subalpine_apothegmatical_ajax  \
# count                  2.746270e+06                           2.746270e+06
# mean                   1.999915e+00                           1.999915e+00
# std                    1.414359e+00                           1.414359e+00
# min                    0.000000e+00                           0.000000e+00
# 25%                    1.000000e+00                           1.000000e+00
# 50%                    2.000000e+00                           2.000000e+00
# 75%                    3.000000e+00                           3.000000e+00
# max                    4.000000e+00                           4.000000e+00
#
#        feature_pistachio_atypical_malison  \
# count                        2.746270e+06
# mean                         1.999915e+00
# std                          1.414359e+00
# min                          0.000000e+00
# 25%                          1.000000e+00
# 50%                          2.000000e+00
# 75%                          3.000000e+00
# max                          4.000000e+00
#
#        feature_symmetrical_spongy_tricentenary  \
# count                             2.746270e+06
# mean                              1.999915e+00
# std                               1.414359e+00
# min                               0.000000e+00
# 25%                               1.000000e+00
# 50%                               2.000000e+00
# 75%                               3.000000e+00
# max                               4.000000e+00
#
#        feature_ungrounded_transpontine_winder  \
# count                            2.746270e+06
# mean                             1.999915e+00
# std                              1.414359e+00
# min                              0.000000e+00
# 25%                              1.000000e+00
# 50%                              2.000000e+00
# 75%                              3.000000e+00
# max                              4.000000e+00
#
#        feature_aseptic_eely_hemiplegia  feature_elemental_easier_alkalinity  \
# count                     2.746270e+06                         2.746270e+06
# mean                      1.999915e+00                         1.999915e+00
# std                       1.414359e+00                         1.414359e+00
# min                       0.000000e+00                         0.000000e+00
# 25%                       1.000000e+00                         1.000000e+00
# 50%                       2.000000e+00                         2.000000e+00
# 75%                       3.000000e+00                         3.000000e+00
# max                       4.000000e+00                         4.000000e+00
#
#        feature_cycloid_zymotic_galloway  ...  target_teager2b_20  \
# count                      2.746270e+06  ...        2.746270e+06
# mean                       1.999915e+00  ...        4.999478e-01
# std                        1.414359e+00  ...        2.236927e-01
# min                        0.000000e+00  ...        0.000000e+00
# 25%                        1.000000e+00  ...        5.000000e-01
# 50%                        2.000000e+00  ...        5.000000e-01
# 75%                        3.000000e+00  ...        5.000000e-01
# max                        4.000000e+00  ...        1.000000e+00
#
#        target_teager2b_60  target_tyler_20  target_tyler_60  target_victor_20  \
# count        2.746270e+06     2.746270e+06     2.746270e+06      2.746270e+06
# mean         4.999478e-01     4.999478e-01     4.999478e-01      4.999971e-01
# std          2.236927e-01     2.236927e-01     2.236927e-01      2.236066e-01
# min          0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 25%          5.000000e-01     5.000000e-01     5.000000e-01      2.500000e-01
# 50%          5.000000e-01     5.000000e-01     5.000000e-01      5.000000e-01
# 75%          5.000000e-01     5.000000e-01     5.000000e-01      5.000000e-01
# max          1.000000e+00     1.000000e+00     1.000000e+00      1.000000e+00
#
#        target_victor_60  target_waldo_20  target_waldo_60  target_xerxes_20  \
# count      2.746270e+06     2.746270e+06     2.746270e+06      2.746270e+06
# mean       4.999725e-01     5.000145e-01     5.000114e-01      5.000152e-01
# std        2.235648e-01     2.231958e-01     2.232122e-01      2.231531e-01
# min        0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 25%        5.000000e-01     2.500000e-01     2.500000e-01      2.500000e-01
# 50%        5.000000e-01     5.000000e-01     5.000000e-01      5.000000e-01
# 75%        5.000000e-01     5.000000e-01     7.500000e-01      5.000000e-01
# max        1.000000e+00     1.000000e+00     1.000000e+00      1.000000e+00
#
#        target_xerxes_60
# count      2.746270e+06
# mean       5.000081e-01
# std        2.231020e-01
# min        0.000000e+00
# 25%        2.500000e-01
# 50%        5.000000e-01
# 75%        5.000000e-01
# max        1.000000e+00
#
# [8 rows x 2789 columns]
# era                                           0
# data_type                                     0
# feature_shaded_hallucinatory_dactylology      0
# feature_itinerant_hexahedral_photoengraver    0
# feature_prudent_pileate_oven                  0
#                                              ..
# target_victor_60                              0
# target_waldo_20                               0
# target_waldo_60                               0
# target_xerxes_20                              0
# target_xerxes_60                              0
# Length: 2791, dtype: int64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6 display(data.describe())
#       7 display(data.isnull().sum())
# ----> 8 display(data.duplicated().sum())
#       9 display(data.corr())
#      10 display(data.skew())
#
# File ~/miniconda3/envs/fantasy/lib/python3.12/site-packages/pandas/core/frame.py:6982, in DataFrame.duplicated(self, subset, keep)
#    6979     vals = (col.values for name, col in self.items() if name in subset)
#    6980     labels, shape = map(list, zip(*map(f, vals)))
# -> 6982     ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
#    6983     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#    6984 return result.__finalize__(self, method="duplicated")
#
# File ~/miniconda3/envs/fantasy/lib/python3.12/site-packages/pandas/core/sorting.py:174, in get_group_index(labels, shape, sort, xnull)
#     172 if not xnull:
#     173     for i, (lab, size) in enumerate(zip(labels, shape)):
# --> 174         labels[i], lshape[i] = maybe_lift(lab, size)
#     176 labels = list(labels)
#     178 # Iteratively process all the labels in chunks sized so less
#     179 # than lib.i8max unique int ids will be required for each chunk
#
# File ~/miniconda3/envs/fantasy/lib/python3.12/site-packages/pandas/core/sorting.py:168, in get_group_index.<locals>.maybe_lift(lab, size)
#     165 def maybe_lift(lab, size: int) -> tuple[np.ndarray, int]:
#     166     # promote nan values (assigned -1 label in lab array)
#     167     # so that all output values are non-negative
# --> 168     return (lab + 1, size + 1) if (lab == -1).any() else (lab, size)
#
# File ~/miniconda3/envs/fantasy/lib/python3.12/site-packages/numpy/core/_methods.py:55, in _any(a, axis, dtype, out, keepdims, where)
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      52           initial=_NoValue, where=True):
#      53     return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# ---> 55 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      56     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      57     if where is True:
#      58         return umr_any(a, axis, dtype, out, keepdims)
#
# KeyboardInterrupt:

# %%
data['data_type'].value_counts()
# Out:
# data_type
# train    2746270
# Name: count, dtype: int64
